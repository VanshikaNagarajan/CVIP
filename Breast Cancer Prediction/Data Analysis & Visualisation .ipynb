# %%
#loading the data
import pandas as pd
data = pd.read_csv("breastCancer.csv")
data
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 0    1000025                5                1                 1
# 1    1002945                5                4                 4
# 2    1015425                3                1                 1
# 3    1016277                6                8                 8
# 4    1017023                4                1                 1
# ..       ...              ...              ...               ...
# 694   776715                3                1                 1
# 695   841769                2                1                 1
# 696   888820                5               10                10
# 697   897471                4                8                 6
# 698   897471                4                8                 8
#
#      marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                    1                2             1                3
# 1                    5                7            10                3
# 2                    1                2             2                3
# 3                    1                3             4                3
# 4                    3                2             1                3
# ..                 ...              ...           ...              ...
# 694                  1                3             2                1
# 695                  1                2             1                1
# 696                  3                7             3                8
# 697                  4                3             4               10
# 698                  5                4             5               10
#
#      normal_nucleoli  mitoses  class
# 0                  1        1      2
# 1                  2        1      2
# 2                  1        1      2
# 3                  7        1      2
# 4                  1        1      2
# ..               ...      ...    ...
# 694                1        1      2
# 695                1        1      2
# 696               10        2      4
# 697                6        1      4
# 698                4        1      4
#
# [699 rows x 11 columns]

# %%
#renaming the column withe= the desried name
data.rename(columns = {'class' : 'Diagnosis'}, inplace = True)

# %%
#printing top 4 data
data.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  Diagnosis
# 0                1        1          2
# 1                2        1          2
# 2                1        1          2
# 3                7        1          2
# 4                1        1          2

# %%
#printing all the column names 
data.columns
# Out:
# Index(['id', 'clump_thickness', 'size_uniformity', 'shape_uniformity',
#        'marginal_adhesion', 'epithelial_size', 'bare_nucleoli',
#        'bland_chromatin', 'normal_nucleoli', 'mitoses', 'Diagnosis'],
#       dtype='object')

# %%
#printing the information of the DataFrame 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 699 non-null    int64
#  1   clump_thickness    699 non-null    int64
#  2   size_uniformity    699 non-null    int64
#  3   shape_uniformity   699 non-null    int64
#  4   marginal_adhesion  699 non-null    int64
#  5   epithelial_size    699 non-null    int64
#  6   bare_nucleoli      699 non-null    object
#  7   bland_chromatin    699 non-null    int64
#  8   normal_nucleoli    699 non-null    int64
#  9   mitoses            699 non-null    int64
#  10  Diagnosis          699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
#printing the stats of the DataFrame 
data.describe()
# Out:
#                  id  clump_thickness  size_uniformity  shape_uniformity  \
# count  6.990000e+02       699.000000       699.000000        699.000000
# mean   1.071704e+06         4.417740         3.134478          3.207439
# std    6.170957e+05         2.815741         3.051459          2.971913
# min    6.163400e+04         1.000000         1.000000          1.000000
# 25%    8.706885e+05         2.000000         1.000000          1.000000
# 50%    1.171710e+06         4.000000         1.000000          1.000000
# 75%    1.238298e+06         6.000000         5.000000          5.000000
# max    1.345435e+07        10.000000        10.000000         10.000000
#
#        marginal_adhesion  epithelial_size  bland_chromatin  normal_nucleoli  \
# count         699.000000       699.000000       699.000000       699.000000
# mean            2.806867         3.216023         3.437768         2.866953
# std             2.855379         2.214300         2.438364         3.053634
# min             1.000000         1.000000         1.000000         1.000000
# 25%             1.000000         2.000000         2.000000         1.000000
# 50%             1.000000         2.000000         3.000000         1.000000
# 75%             4.000000         4.000000         5.000000         4.000000
# max            10.000000        10.000000        10.000000        10.000000
#
#           mitoses   Diagnosis
# count  699.000000  699.000000
# mean     1.589413    2.689557
# std      1.715078    0.951273
# min      1.000000    2.000000
# 25%      1.000000    2.000000
# 50%      1.000000    2.000000
# 75%      1.000000    4.000000
# max     10.000000    4.000000

# %%
#to drop any duplicates 
data.drop_duplicates(inplace = True)

# %%
#printing the number of rows and columns in the DataFrame 
num_rows, num_columns = data.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 691
# Number of columns: 11

# %%
#to check the missing value 
missing_value = data.isnull().sum()
missing_value
# Out:
# id                   0
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# Diagnosis            0
# dtype: int64

# %%
#data.dropna(subset = ['bare_nucleoli'], inplace = True)

# %%
#missing_value = data.isnull().sum()
#missing_value

# %%
#to tranform 2 and 4 to binary code 0 and 1 for M and B.
from sklearn.preprocessing import LabelEncoder
new_label = LabelEncoder()
data['Diagnosis'] = new_label.fit_transform(data['Diagnosis'])
data
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 0    1000025                5                1                 1
# 1    1002945                5                4                 4
# 2    1015425                3                1                 1
# 3    1016277                6                8                 8
# 4    1017023                4                1                 1
# ..       ...              ...              ...               ...
# 694   776715                3                1                 1
# 695   841769                2                1                 1
# 696   888820                5               10                10
# 697   897471                4                8                 6
# 698   897471                4                8                 8
#
#      marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                    1                2             1                3
# 1                    5                7            10                3
# 2                    1                2             2                3
# 3                    1                3             4                3
# 4                    3                2             1                3
# ..                 ...              ...           ...              ...
# 694                  1                3             2                1
# 695                  1                2             1                1
# 696                  3                7             3                8
# 697                  4                3             4               10
# 698                  5                4             5               10
#
#      normal_nucleoli  mitoses  Diagnosis
# 0                  1        1          0
# 1                  2        1          0
# 2                  1        1          0
# 3                  7        1          0
# 4                  1        1          0
# ..               ...      ...        ...
# 694                1        1          0
# 695                1        1          0
# 696               10        2          1
# 697                6        1          1
# 698                4        1          1
#
# [691 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#to check the importance of the features 
correlation = data.corr()
target = correlation['Diagnosis'].abs()
features = target.sort_values(ascending = False).index
features
# Out:
# /var/folders/9d/664tkyps6ngbzjv82lvkd5_r0000gn/T/ipykernel_48993/3399192761.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data.corr()
# Index(['Diagnosis', 'size_uniformity', 'shape_uniformity', 'bland_chromatin',
#        'clump_thickness', 'normal_nucleoli', 'marginal_adhesion',
#        'epithelial_size', 'mitoses', 'id'],
#       dtype='object')

# %%
#to visualise the distribution of Bland Chromatin by Diagnosis
sns.countplot(data = data, x = 'bland_chromatin', hue = 'Diagnosis')
plt.title('Distribution of Bland Chromatin by Diagnosis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#to visualise the distribution of Clump thickness by Diagnosis
sns.countplot(data = data, x = 'clump_thickness', hue = 'Diagnosis')
plt.title('Distribution of Clump Thickness by Diagnosis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#to visualise the spread of the data of clump thickness by diagonsis 
sns.boxplot(data = data, x = 'Diagnosis', y = 'clump_thickness')
plt.title('Box Plot of CLump Thickness by Diagnosis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#to visualise the spread of the data of Bland Chromatin by diagnosis
sns.boxplot(data = data, x = 'Diagnosis', y = 'bland_chromatin')
plt.title('Box Plot of Bland Chromatin by Diagnosis')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#to visualize the combination of diagnosis
sns.pairplot(data, hue = 'Diagnosis')

# %%
from sklearn.model_selection import train_test_split
X = data.drop(columns = ['Diagnosis'])
Y = data['Diagnosis']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

#to check the missing values in the training and testing dataset 
missing_train = X_train.isnull().sum()
print("Missing values in training set:")
print(missing_train)

# Check for missing values in the testing set
missing_test = X_test.isnull().sum()
print("\nMissing values in testing set:")
print(missing_test)
# Out:
# Missing values in training set:
# id                   0
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# dtype: int64
#
# Missing values in testing set:
# id                   0
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# dtype: int64

# %%
#to check the column bare_nucleoli if it has any non-numeri value 
non_numeric_bare_nucleoli = data[~data['bare_nucleoli'].str.isnumeric()].dropna()

print(non_numeric_bare_nucleoli)
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 23   1057013                8                4                 5
# 40   1096800                6                6                 6
# 139  1183246                1                1                 1
# 145  1184840                1                1                 3
# 158  1193683                1                1                 2
# 164  1197510                5                1                 1
# 235  1241232                3                1                 4
# 249   169356                3                1                 1
# 275   432809                3                1                 3
# 292   563649                8                8                 8
# 294   606140                1                1                 1
# 297    61634                5                4                 3
# 315   704168                4                6                 5
# 321   733639                3                1                 1
# 411  1238464                1                1                 1
# 617  1057067                1                1                 1
#
#      marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 23                   1                2             ?                7
# 40                   9                6             ?                7
# 139                  1                1             ?                2
# 145                  1                2             ?                2
# 158                  1                3             ?                1
# 164                  1                2             ?                3
# 235                  1                2             ?                3
# 249                  1                2             ?                3
# 275                  1                2             ?                2
# 292                  1                2             ?                6
# 294                  1                2             ?                2
# 297                  1                2             ?                2
# 315                  6                7             ?                4
# 321                  1                2             ?                3
# 411                  1                1             ?                2
# 617                  1                1             ?                1
#
#      normal_nucleoli  mitoses  Diagnosis
# 23                 3        1          1
# 40                 8        1          0
# 139                1        1          0
# 145                1        1          0
# 158                1        1          0
# 164                1        1          0
# 235                1        1          0
# 249                1        1          0
# 275                1        1          0
# 292               10        1          1
# 294                1        1          0
# 297                3        1          0
# 315                9        1          0
# 321                1        1          0
# 411                1        1          0
# 617                1        1          0

# %%
#to change the datatype and then convert the string value to a numeric character by replacing it with the median value of that column 
data['bare_nucleoli'] = data['bare_nucleoli'].astype(str)
median_value = data['bare_nucleoli'][data['bare_nucleoli'].str.isnumeric()].median()
data['bare_nucleoli'] = data['bare_nucleoli'].replace('?', median_value).astype(int)
